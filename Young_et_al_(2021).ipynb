# %% [markdown]
# Young et al (2021). A Meta-Analysis of Transactional Leadership and Follower Performance: Double-Edged Effects of LMX and Empowerment

# %% [markdown]
# **Intro**
#
# Meta-analytic studies haven't yet:
# *   uncovered the relationship between transactional leadership (TL) and follower performance, and...
# *   the mechanisms that explain this complex relationship. *   Use of social exchange theory (SET) and self-determination theory (SDT) to uncover double-edged consequences.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
